# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as BS
import time

# %%
key='d0882ea7c5df3b123a9450d91929525f23bfa3ad'
headers={'User-Agent':'AsherKetchums Video Game Analysis Project'}
offset = 0

def print_refresh(string):
    print(string,
          '\t\t\t\t\t\t\t\t\t\t\t\t',
          end='\r',
          flush = True
         )
    
def pause_update(n):
    for i in range(n):
        print_refresh(f'Waiting {n} seconds: {n-i} seconds remaining')
        time.sleep(1)
    print(f'Finished with {n} second wait')

# %%
games_df=pd.read_csv('../data/games_df.csv')

game_ids=games_df['game_id'].unique()

game_ids=pd.DataFrame(game_ids)
game_ids_list=game_ids[0].tolist()
# Out:
# C:\Users\asher\AppData\Local\Temp\ipykernel_17348\3940341832.py:1: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_df=pd.read_csv('../data/games_df.csv')

# %%
len(game_ids_list)
# Out:
# 14469

# %%
game_ids_1=game_ids_list[2336:3263]
len(games1)
# Out:
# 1395

# %%
len(game_ids_1)
# Out:
# 927

# %%
#ALL-GAMES
game_url = 'https://www.giantbomb.com/api/game/'

games1=[]

for ids in game_ids_1:
    #offset=0
    
    params={
    'api_key':key,
    'format':'json',
    'field_list':'characters,concepts,deck,developers,first_appearance_characters,first_appearance_concepts,first_appearance_locations,first_appearance_objects,franchises,genres,id,image,killed_characters,locations,number_of_user_reviews,platforms,publishers,themes,name,original,game_rating,original_release_date',
    #'limit':50, #Changed limit due to weight of queries per call on the server. I believe this is why 503 error was so common
    #'offset':offset
        }
    
    try:
        response = requests.get(f'{game_url}{ids}/',params=params,headers=headers,timeout=30)
        res=response.json()
        print(res)
    except (requests.exceptions.ReadTimeout, requests.exceptions.ConnectionError) as re:
        print(f'Network Error:{re} damn')
        pause_update(600)
        continue

    if response.status_code == 204:
        print('2 0 not 4 sure if this is necessary')
        pause_update(600)
        continue

    if response.status_code == 420:
        print('420 and chill bruh')
        pause_update(600)
        continue

    if response.status_code == 503:
        print('server overload (503)')
        pause_update(60)
        continue
    
    response.raise_for_status()

    try:
        res=response.json()
    except ValueError:
        print('Value Error, jason')
        pause_update(600)
        continue
            
    result = res.get('results')
    if result: 
        games1.append(result)
        
    time.sleep(30)
# Out:
# {'error': 'OK', 'limit': 1, 'offset': 0, 'number_of_page_results': 1, 'number_of_total_results': 1, 'status_code': 1, 'results': {'deck': "The tale of Soul Calibur continues in the series's fourth entry, adding a variety of new game modes and features (including an in-depth character creation system).", 'id': 9855, 'image': {'icon_url': 'https://www.giantbomb.com/a/uploads/square_avatar/8/87790/2126450-box_sc3.png', 'medium_url': 'https://www.giantbomb.com/a/uploads/scale_medium/8/87790/2126450-box_sc3.png', 'screen_url': 'https://www.giantbomb.com/a/uploads/screen_medium/8/87790/2126450-box_sc3.png', 'screen_large_url': 'https://www.giantbomb.com/a/uploads/screen_kubrick/8/87790/2126450-box_sc3.png', 'small_url': 'https://www.giantbomb.com/a/uploads/scale_small/8/87790/2126450-box_sc3.png', 'super_url': 'https://www.giantbomb.com/a/uploads/scale_large/8/87790/2126450-box_sc3.png', 'thumb_url': 'https://www.giantbomb.com/a/uploads/scale_avatar/8/87790/2126450-box_sc3.png', 'tiny_url': 'https://www.giantbomb.com/a/uploads/square_mini/8/87790/2126450-box_sc3.png', 'original_
# {'error': 'OK', 'limit': 1, 'offset': 0, 'number_of_page_results': 1, 'number_of_total_results': 1, 'status_code': 1, 'results': {'deck': 'Made Man is a mafia-themed 3rd person shooter in which the player takes the role of Joey Verola, a made man in a crime syndicate. The story for the game was written by David Fisher with assistance from the former mafioso Bill Bonanno.', 'id': 9859, 'image': {'icon_url': 'https://www.giantbomb.com/a/uploads/square_avatar/0/1550/272850-mademan_front.jpg', 'medium_url': 'https://www.giantbomb.com/a/uploads/scale_medium/0/1550/272850-mademan_front.jpg', 'screen_url': 'https://www.giantbomb.com/a/uploads/screen_medium/0/1550/272850-mademan_front.jpg', 'screen_large_url': 'https://www.giantbomb.com/a/uploads/screen_kubrick/0/1550/272850-mademan_front.jpg', 'small_url': 'https://www.giantbomb.com/a/uploads/scale_small/0/1550/272850-mademan_front.jpg', 'super_url': 'https://www.giantbomb.com/a/uploads/scale_large/0/1550/272850-mademan_front.jpg', 'thumb_url': 'https://www.giantbomb.com/a/uploads/scale_avatar/0/1550/272850-mademan_front.jpg', 'tiny_url': 'https://www.giantbomb.com/a/uploads/square_mini/0/1550/272850-mademan_front.jpg', 'original_url': 'https://www.giantbomb.com/a/uploads/original/0/1550/272850-mademan_front.jpg', 'image_tags': 'All Images,Box Art'}, 'name': 'Made Man: Confessions of the Family Blood', 'number_of_user_reviews': 0, 'original_release_date': '2007-04-23', 'platforms': [{'api_detail_url': 'https://www.giantbomb.com/api/platform/3045-19/', 'id': 19, 'name': 'PlayStation 2', 'site_detail_url': 'https://www.giantbomb.com/playstation-2/3045-19/', 'abbreviation': 'PS2'}, {'api_detail_url': 'https://www.giantbomb.com/api/platform/3045-94/', 'id': 94, 'name': 'PC', 'site_detail_url': 'https://www.giantbomb.com/pc/3045-94/', 'abbreviation': 'PC'}], 'characters': None, 'concepts': [{'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-55/', 'id': 55, 'name': 'Cover System', 'site_detail_url': 'https://www.giantbomb.com/cover-system/3015-55/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-84/', 'id': 84, 'name': 'Sniping', 'site_detail_url': 'https://www.giantbomb.com/sniping/3015-84/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-85/', 'id': 85, 'name': 'Headshot', 'site_detail_url': 'https://www.giantbomb.com/headshot/3015-85/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-112/', 'id': 112, 'name': 'Destructible Cover', 'site_detail_url': 'https://www.giantbomb.com/destructible-cover/3015-112/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-226/', 'id': 226, 'name': 'Flashback', 'site_detail_url': 'https://www.giantbomb.com/flashback/3015-226/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-309/', 'id': 309, 'name': 'Explosion', 'site_detail_url': 'https://www.giantbomb.com/explosion/3015-309/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-378/', 'id': 378, 'name': 'Crouch', 'site_detail_url': 'https://www.giantbomb.com/crouch/3015-378/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-383/', 'id': 383, 'name': 'Linear Gameplay', 'site_detail_url': 'https://www.giantbomb.com/linear-gameplay/3015-383/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-464/', 'id': 464, 'name': 'Third-Person Perspective', 'site_detail_url': 'https://www.giantbomb.com/third-person-perspective/3015-464/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-505/', 'id': 505, 'name': 'Reload', 'site_detail_url': 'https://www.giantbomb.com/reload/3015-505/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-512/', 'id': 512, 'name': 'Blood', 'site_detail_url': 'https://www.giantbomb.com/blood/3015-512/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-575/', 'id': 575, 'name': 'Currency', 'site_detail_url': 'https://www.giantbomb.com/currency/3015-575/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/ ...
# {'error': 'OK', 'limit': 1, 'offset': 0, 'number_of_page_results': 1, 'number_of_total_results': 1, 'status_code': 1, 'results': {'deck': 'Rock Band expands on the concepts Harmonix established in its Guitar Hero franchise by allowing players to play guitar, bass, drums, and sing to a variety of songs from various sub-genres and time periods.', 'id': 9860, 'image': {'icon_url': 'https://www.giantbomb.com/a/uploads/square_avatar/0/4/175816-rock_band.jpg', 'medium_url': 'https://www.giantbomb.com/a/uploads/scale_medium/0/4/175816-rock_band.jpg', 'screen_url': 'https://www.giantbomb.com/a/uploads/screen_medium/0/4/175816-rock_band.jpg', 'screen_large_url': 'https://www.giantbomb.com/a/uploads/screen_kubrick/0/4/175816-rock_band.jpg', 'small_url': 'https://www.giantbomb.com/a/uploads/scale_small/0/4/175816-rock_band.jpg', 'super_url': 'https://www.giantbomb.com/a/uploads/scale_large/0/4/175816-rock_band.jpg', 'thumb_url': 'https://www.giantbomb.com/a/uploads/scale_avatar/0/4/175816-rock_band.jpg', 'tiny_url': 'https://www.giantbomb.com/a/uploads/square_mini/0/4/175816-rock_band.jpg', 'original_url': 'https://www.giantbomb.com/a/uploads/original/0/4/175816-rock_band.jpg', 'image_tags': 'All Images,Box Art'}, 'name': 'Rock Band', 'number_of_user_reviews': 0, 'original_release_date': '2007-11-20', 'platforms': [{'api_detail_url': 'https://www.giantbomb.com/api/platform/3045-19/', 'id': 19, 'name': 'PlayStation 2', 'site_detail_url': 'https://www.giantbomb.com/playstation-2/3045-19/', 'abbreviation': 'PS2'}, {'api_detail_url': 'https://www.giantbomb.com/api/platform/3045-20/', 'id': 20, 'name': 'Xbox 360', 'site_detail_url': 'https://www.giantbomb.com/xbox-360/3045-20/', 'abbreviation': 'X360'}, {'api_detail_url': 'https://www.giantbomb.com/api/platform/3045-35/', 'id': 35, 'name': 'PlayStation 3', 'site_detail_url': 'https://www.giantbomb.com/playstation-3/3045-35/', 'abbreviation': 'PS3'}, {'api_detail_url': 'https://www.giantbomb.com/api/platform/3045-36/', 'id': 36, 'name': 'Wii', 'site_detail_url': 'https://www.giantbomb.com/wii/3045-36/', 'abbreviation': 'Wii'}], 'characters': None, 'concepts': [{'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-18/', 'id': 18, 'name': 'Combo', 'site_detail_url': 'https://www.giantbomb.com/combo/3015-18/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-29/', 'id': 29, 'name': 'Achievements', 'site_detail_url': 'https://www.giantbomb.com/achievements/3015-29/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-30/', 'id': 30, 'name': 'Leaderboard', 'site_detail_url': 'https://www.giantbomb.com/leaderboard/3015-30/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-44/', 'id': 44, 'name': 'Button Mashing', 'site_detail_url': 'https://www.giantbomb.com/button-mashing/3015-44/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-89/', 'id': 89, 'name': 'Push to Talk', 'site_detail_url': 'https://www.giantbomb.com/push-to-talk/3015-89/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-106/', 'id': 106, 'name': 'Loading Screen', 'site_detail_url': 'https://www.giantbomb.com/loading-screen/3015-106/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-108/', 'id': 108, 'name': 'Cooperative Play', 'site_detail_url': 'https://www.giantbomb.com/cooperative-play/3015-108/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-114/', 'id': 114, 'name': 'Peripheral Usage', 'site_detail_url': 'https://www.giantbomb.com/peripheral-usage/3015-114/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-124/', 'id': 124, 'name': 'Hammer On & Pull Off', 'site_detail_url': 'https://www.giantbomb.com/hammer-on-and-pull-off/3015-124/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-140/', 'id': 140, 'name': 'Star Power', 'site_detail_url': 'https://www.giantbomb.com/star-power/3015-140/'}, {'api_detail_url': 'https://www.giantbomb.com/api/concept/3015-141/', 'id': 141, 'name': 'Fu ...

# %%
len(games1)
# Out:
# 1395

# %%
games1_5=pd.DataFrame(games1)

# %%
games1_5.to_csv('games6.csv')
